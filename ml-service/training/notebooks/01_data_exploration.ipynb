# %%
import pandas as pd


column_names = [
    'duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes',
    'land', 'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in',
    'num_compromised', 'root_shell', 'su_attempted', 'num_root',
    'num_file_creations', 'num_shells', 'num_access_files', 'num_outbound_cmds',
    'is_host_login', 'is_guest_login', 'count', 'srv_count', 'serror_rate',
    'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
    'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
    'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate',
    'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate',
    'dst_host_serror_rate', 'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
    'dst_host_srv_rerror_rate', 'label', 'difficulty_level'
]

train_df = pd.read_csv('/Users/alex/dev/sonic/ml-service/training/data/KDDTrain+.txt', header=None, names = column_names)

print("Shape:", train_df.shape)  # Should show (125973, 43)
print("First 5 rows: ", train_df.head())

print("\nColumn names:")
print(train_df.columns.tolist())
print("Len of columns:", str(len(train_df.columns.tolist())))


print("Stats over data set:")
train_df.describe()
# Out:
# Shape: (125973, 43)
# First 5 rows:     duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# ...

# %%
train_df['label'].unique()
#train_df['label'].nunique()
# Out:
# array(['normal', 'neptune', 'warezclient', 'ipsweep', 'portsweep',
#        'teardrop', 'nmap', 'satan', 'smurf', 'pod', 'back',
#        'guess_passwd', 'ftp_write', 'multihop', 'rootkit',
#        'buffer_overflow', 'imap', 'warezmaster', 'phf', 'land',
#        'loadmodule', 'spy', 'perl'], dtype=object)

# %%
train_df['label'].value_counts()
# Out:
# label
# normal             67343
# neptune            41214
# satan               3633
# ipsweep             3599
# portsweep           2931
# smurf               2646
# nmap                1493
# back                 956
# teardrop             892
# warezclient          890
# pod                  201
# guess_passwd          53
# buffer_overflow       30
# warezmaster           20
# land                  18
# imap                  11
# rootkit               10
# loadmodule             9
# ftp_write              8
# multihop               7
# phf                    4
# perl                   3
# spy                    2
# Name: count, dtype: int64

# %%
print("Number of unique labels:", train_df['label'].nunique())
print("\nAll unique labels:")
print(train_df['label'].unique())

print("\nLabel distribution:")
label_counts = train_df['label'].value_counts()
print(label_counts)
# Out:
# Number of unique labels: 23
#
# All unique labels:
# ['normal' 'neptune' 'warezclient' 'ipsweep' 'portsweep' 'teardrop' 'nmap'
#  'satan' 'smurf' 'pod' 'back' 'guess_passwd' 'ftp_write' 'multihop'
#  'rootkit' 'buffer_overflow' 'imap' 'warezmaster' 'phf' 'land'
#  'loadmodule' 'spy' 'perl']
#
# Label distribution:
# label
# normal             67343
# neptune            41214
# satan               3633
# ipsweep             3599
# portsweep           2931
# smurf               2646
# nmap                1493
# back                 956
# teardrop             892
# warezclient          890
# pod                  201
# guess_passwd          53
# buffer_overflow       30
# warezmaster           20
# land                  18
# imap                  11
# rootkit               10
# loadmodule             9
# ftp_write              8
# multihop               7
# phf                    4
# perl                   3
# spy                    2
# Name: count, dtype: int64

# %%
print("\nLabel percentage:")
label_percentage = train_df['label'].value_counts(normalize=True) * 100
print(label_percentage)
# Out:
# Label percentage:
# label
# normal             53.458281
# neptune            32.716534
# satan               2.883951
# ipsweep             2.856961
# portsweep           2.326689
# smurf               2.100450
# nmap                1.185175
# back                0.758893
# teardrop            0.708088
# warezclient         0.706501
# pod                 0.159558
# guess_passwd        0.042073
# buffer_overflow     0.023815
# warezmaster         0.015876
# land                0.014289
# imap                0.008732
# rootkit             0.007938
# loadmodule          0.007144
# ftp_write           0.006351
# multihop            0.005557
# phf                 0.003175
# perl                0.002381
# spy                 0.001588
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

label_counts.plot.bar(figsize=(12, 6))
plt.title('Distribution of Attack Types in Training Data')
plt.xlabel('Label')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
print("Find categorical features")
categorical_features = train_df.select_dtypes(include=['object']).columns.tolist()
print(categorical_features)
print("Number of categorical features:", str(len(categorical_features)))
# Out:
# Find categorical features
# ['protocol_type', 'service', 'flag', 'label']
# Number of categorical features: 4

# %%
train_df['protocol_type'].unique()
# Out:
# array(['tcp', 'udp', 'icmp'], dtype=object)

# %%
train_df['service'].unique()
# Out:
# array(['ftp_data', 'other', 'private', 'http', 'remote_job', 'name',
#        'netbios_ns', 'eco_i', 'mtp', 'telnet', 'finger', 'domain_u',
#        'supdup', 'uucp_path', 'Z39_50', 'smtp', 'csnet_ns', 'uucp',
#        'netbios_dgm', 'urp_i', 'auth', 'domain', 'ftp', 'bgp', 'ldap',
#        'ecr_i', 'gopher', 'vmnet', 'systat', 'http_443', 'efs', 'whois',
#        'imap4', 'iso_tsap', 'echo', 'klogin', 'link', 'sunrpc', 'login',
#        'kshell', 'sql_net', 'time', 'hostnames', 'exec', 'ntp_u',
#        'discard', 'nntp', 'courier', 'ctf', 'ssh', 'daytime', 'shell',
#        'netstat', 'pop_3', 'nnsp', 'IRC', 'pop_2', 'printer', 'tim_i',
#        'pm_dump', 'red_i', 'netbios_ssn', 'rje', 'X11', 'urh_i',
#        'http_8001', 'aol', 'http_2784', 'tftp_u', 'harvest'], dtype=object)

# %%
train_df['service'].unique()
# Out:
# array(['ftp_data', 'other', 'private', 'http', 'remote_job', 'name',
#        'netbios_ns', 'eco_i', 'mtp', 'telnet', 'finger', 'domain_u',
#        'supdup', 'uucp_path', 'Z39_50', 'smtp', 'csnet_ns', 'uucp',
#        'netbios_dgm', 'urp_i', 'auth', 'domain', 'ftp', 'bgp', 'ldap',
#        'ecr_i', 'gopher', 'vmnet', 'systat', 'http_443', 'efs', 'whois',
#        'imap4', 'iso_tsap', 'echo', 'klogin', 'link', 'sunrpc', 'login',
#        'kshell', 'sql_net', 'time', 'hostnames', 'exec', 'ntp_u',
#        'discard', 'nntp', 'courier', 'ctf', 'ssh', 'daytime', 'shell',
#        'netstat', 'pop_3', 'nnsp', 'IRC', 'pop_2', 'printer', 'tim_i',
#        'pm_dump', 'red_i', 'netbios_ssn', 'rje', 'X11', 'urh_i',
#        'http_8001', 'aol', 'http_2784', 'tftp_u', 'harvest'], dtype=object)

# %%
print("Null columns:")
train_df.isnull().sum()
# Out:
# Null columns:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
print(f"Total rows: {len(train_df)}")
print(f"Duplicate rows: {train_df.duplicated().sum()}")
print(f"Unique rows: {len(train_df.drop_duplicates())}")
print("\n" + "="*50 + "\n")
# Out:
# Total rows: 125973
# Duplicate rows: 0
# Unique rows: 125973
#
# ...

# %%
numerical_cols = train_df.select_dtypes(include=['int64', 'float64']).columns
negative_counts = (train_df[numerical_cols] < 0).sum()
print("Columns with negative values:")
print(negative_counts[negative_counts > 0])
if negative_counts.sum() == 0:
    print("✅ No negative values found!")
# Out:
# Columns with negative values:
# Series([], dtype: int64)
# ✅ No negative values found!

# %%
print("NaN columns:")
train_df.isna().sum()
# Out:
# NaN columns:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
train_df['binary_label'] = (train_df['label'] != 'normal').astype(int)
train_df['binary_label']
# Out:
# 0         0
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 125968    1
# 125969    0
# 125970    0
# 125971    1
# 125972    0
# Name: binary_label, Length: 125973, dtype: int64

# %%
train_df['binary_label'].value_counts(normalize = True) * 100
# Out:
# binary_label
# 0    53.458281
# 1    46.541719
# Name: proportion, dtype: float64

# %%
train_df['attack_type'] = train_df['label'].apply(
    lambda x: 'Normal' if x == 'normal' else 'Attack'
)

train_df['attack_type']
# Out:
# 0         Normal
# 1         Normal
# 2         Attack
# 3         Normal
# 4         Normal
#            ...
# 125968    Attack
# 125969    Normal
# 125970    Normal
# 125971    Attack
# 125972    Normal
# Name: attack_type, Length: 125973, dtype: object

# %%
print("Binary label distribution:")
print(train_df['attack_type'].value_counts())
print("\nPercentage:")
print(train_df['attack_type'].value_counts(normalize=True) * 100)
# Out:
# Binary label distribution:
# attack_type
# Normal    67343
# Attack    58630
# Name: count, dtype: int64
#
# Percentage:
# attack_type
# Normal    53.458281
# Attack    46.541719
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 5))

# Subplot 1: Top 10 specific attack types
plt.subplot(1, 2, 1)
train_df['label'].value_counts().head(10).plot.bar(color='steelblue', edgecolor='black')
plt.title('Top 10 Most Common Labels', fontsize=14, fontweight='bold')
plt.xlabel('Label', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)

# Subplot 2: Binary classification
plt.subplot(1, 2, 2)
colors = ['green', 'red']
train_df['attack_type'].value_counts().plot.bar(color=colors, edgecolor='black')
plt.title('Normal vs Attack Traffic', fontsize=14, fontweight='bold')
plt.xlabel('Traffic Type', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# Print exact numbers
print("\nExact counts:")
print(train_df['attack_type'].value_counts())
# Out:
# Exact counts:
# attack_type
# Normal    67343
# Attack    58630
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14, 5))

# Subplot 1: Duration histogram (zoomed to 0-100 seconds)
plt.subplot(1, 2, 1)
train_df['duration'].hist(bins=50, color='skyblue', edgecolor='black')
plt.title('Duration Distribution (0-100 seconds)', fontsize=14, fontweight='bold')
plt.xlabel('Duration (seconds)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xlim(0, 100)
plt.grid(axis='y', alpha=0.3)

# Subplot 2: Same with log scale Y-axis
plt.subplot(1, 2, 2)
train_df['duration'].hist(bins=50, color='lightcoral', edgecolor='black')
plt.title('Duration Distribution (Log Scale)', fontsize=14, fontweight='bold')
plt.xlabel('Duration (seconds)', fontsize=12)
plt.ylabel('Frequency (log scale)', fontsize=12)
plt.yscale('log')
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# Statistics
print(f"Duration statistics:")
print(f"Min: {train_df['duration'].min()}")
print(f"Max: {train_df['duration'].max()}")
print(f"Mean: {train_df['duration'].mean():.2f}")
print(f"Median: {train_df['duration'].median():.2f}")
# Out:
# Duration statistics:
# Min: 0
# Max: 42908
# Mean: 287.14
# Median: 0.00

# %%
# Select interesting features to compare
features_to_compare = ['duration', 'src_bytes', 'dst_bytes', 'count']

plt.figure(figsize=(15, 10))

for i, feature in enumerate(features_to_compare, 1):
    plt.subplot(2, 2, i)
    
    # Separate data
    normal_data = train_df[train_df['attack_type'] == 'Normal'][feature]
    attack_data = train_df[train_df['attack_type'] == 'Attack'][feature]
    
    # Create overlapping histograms
    plt.hist([normal_data, attack_data], 
             bins=30, 
             label=['Normal', 'Attack'],
             color=['green', 'red'],
             alpha=0.6,
             edgecolor='black')
    
    plt.title(f'{feature}: Normal vs Attack', fontsize=13, fontweight='bold')
    plt.xlabel(feature, fontsize=11)
    plt.ylabel('Frequency (log scale)', fontsize=11)
    plt.legend(loc='upper right')
    plt.yscale('log')  # Log scale to see both distributions
    plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# Print statistics comparison
print("\nMean values comparison:")
comparison = train_df.groupby('attack_type')[features_to_compare].mean()
print(comparison)
# Out:
# Mean values comparison:
#                duration     src_bytes     dst_bytes       count
# attack_type
# Attack       423.320689  82820.141327  37524.482159  154.849991
# Normal       168.587396  13133.279331   4329.685223   22.517945

# %%
import seaborn as sns

features_for_box = ['duration', 'src_bytes', 'dst_bytes']

plt.figure(figsize=(15, 5))

for i, feature in enumerate(features_for_box, 1):
    plt.subplot(1, 3, i)
    
    # Box plot
    sns.boxplot(data=train_df, x='attack_type', y=feature, palette=['green', 'red'])
    plt.title(f'{feature} Distribution', fontsize=13, fontweight='bold')
    plt.ylabel(f'{feature} (log scale)', fontsize=11)
    plt.yscale('log')  # Log scale
    plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/vn/fb81pz8j4hb6ft73l7t2j5pw0000gn/T/ipykernel_73497/4211522711.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=train_df, x='attack_type', y=feature, palette=['green', 'red'])
# /var/folders/vn/fb81pz8j4hb6ft73l7t2j5pw0000gn/T/ipykernel_73497/4211522711.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=train_df, x='attack_type', y=feature, palette=['green', 'red'])
# /var/folders/vn/fb81pz8j4hb6ft73l7t2j5pw0000gn/T/ipykernel_73497/4211522711.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
print("="*60)
print("SUMMARY: Normal vs Attack Comparison")
print("="*60)

# Select numerical features to compare
numeric_features = ['duration', 'src_bytes', 'dst_bytes', 'count', 
                   'srv_count', 'serror_rate', 'same_srv_rate']

summary = train_df.groupby('attack_type')[numeric_features].agg(['mean', 'median', 'std'])
print(summary)

print("\n" + "="*60)
print("KEY INSIGHTS TO LOOK FOR:")
print("="*60)
print("1. Features where mean/median differ a lot between Normal and Attack")
print("2. Features with low standard deviation (more consistent)")
print("3. Features that could help distinguish normal from malicious traffic")
# Out:
# ...
# SUMMARY: Normal vs Attack Comparison
# ...
#                duration                         src_bytes         \
#                    mean median          std          mean median
# attack_type
# Attack       423.320689    0.0  3547.684533  82820.141327    0.0
# Normal       168.587396    0.0  1304.452127  13133.279331  233.0
#
#                               dst_bytes                            count  ...  \
#                       std          mean median           std        mean  ...
# attack_type                                                               ...
# Attack       8.593025e+06  37524.482159    0.0  5.893991e+06  154.849991  ...
# Normal       4.181131e+05   4329.685223  379.0  6.546282e+04   22.517945  ...
#
#                          srv_count                   serror_rate         \
#                     std       mean median        std        mean median
# attack_type
# Attack       124.334483  27.797885   10.0  84.710761    0.595808    1.0
# ...

# %%
print("="*60)
print("STEP 1: Create Binary Labels")
print("="*60)

# Create binary label column
train_df['binary_label'] = (train_df['label'] != 'normal').astype(int)

# Verify
print("\nBinary label distribution:")
print(train_df['binary_label'].value_counts())

# Show mapping examples
print("\nExample mappings:")
print(train_df[['label', 'binary_label']].drop_duplicates().head(10))

print("\n✅ Binary labels created!")
# Out:
# ...
# STEP 1: Create Binary Labels
# ...
#
# Binary label distribution:
# binary_label
# 0    67343
# 1    58630
# Name: count, dtype: int64
#
# Example mappings:
#            label  binary_label
# 0         normal             0
# 2        neptune             1
# 13   warezclient             1
# 17       ipsweep             1
# 33     portsweep             1
# 46      teardrop             1
# 56          nmap             1
# 62         satan             1
# 138        smurf             1
# 211          pod             1
#
# ✅ Binary labels created!

# %%
# Cell 28: Separate Features from Labels
print("="*60)
print("STEP 2: Separate Features (X) from Labels (y)")
print("="*60)

# Define columns to drop
columns_to_drop = ['label', 'binary_label', 'difficulty_level']

# If you created attack_type column, drop it too
if 'attack_type' in train_df.columns:
    columns_to_drop.append('attack_type')

# Create feature matrix (X) and target vector (y)
X = train_df.drop(columns=columns_to_drop)
y = train_df['binary_label']

print(f"Feature matrix (X) shape: {X.shape}")
print(f"Target vector (y) shape: {y.shape}")
print(f"\nFeatures (columns): {X.shape[1]}")
print(f"Samples (rows): {X.shape[0]}")

# Show feature columns
print(f"\nFeature columns:")
print(X.columns.tolist())

# Verify target distribution
print(f"\nTarget distribution:")
print(y.value_counts())

print("\n✅ Features and labels separated!")
# Out:
# ...
# STEP 2: Separate Features (X) from Labels (y)
# ...
# Feature matrix (X) shape: (125973, 41)
# Target vector (y) shape: (125973,)
#
# Features (columns): 41
# Samples (rows): 125973
#
# Feature columns:
# ['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells', 'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count', 'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate', 'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate']
#
# Target distribution:
# binary_label
# 0    67343
# 1    58630
# ...

# %%
# Cell 29: Encode Categorical Features
print("="*60)
print("STEP 3: Encode Categorical Features")
print("="*60)

# Check current categorical columns
categorical_cols = X.select_dtypes(include=['object']).columns.tolist()
print(f"Categorical columns to encode: {categorical_cols}")
print(f"Number of categorical columns: {len(categorical_cols)}")

# Show unique values count
print("\nUnique values per categorical column:")
for col in categorical_cols:
    print(f"  {col}: {X[col].nunique()} unique values")

# Perform one-hot encoding
X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=False)

print(f"\n--- Before encoding ---")
print(f"Shape: {X.shape}")
print(f"Columns: {X.shape[1]}")

print(f"\n--- After encoding ---")
print(f"Shape: {X_encoded.shape}")
print(f"Columns: {X_encoded.shape[1]}")

print(f"\nNew columns created: {X_encoded.shape[1] - X.shape[1]}")

# Show some new column names
print(f"\nExample encoded columns:")
encoded_cols = [col for col in X_encoded.columns if '_' in col]
print(encoded_cols[:15])  # Show first 15

print("\n✅ Categorical features encoded!")
# Out:
# ...
# STEP 3: Encode Categorical Features
# ...
# Categorical columns to encode: ['protocol_type', 'service', 'flag']
# Number of categorical columns: 3
#
# Unique values per categorical column:
#   protocol_type: 3 unique values
#   service: 70 unique values
#   flag: 11 unique values
#
# --- Before encoding ---
# Shape: (125973, 41)
# Columns: 41
#
# --- After encoding ---
# Shape: (125973, 122)
# Columns: 122
#
# New columns created: 81
#
# Example encoded columns:
# ['src_bytes', 'dst_bytes', 'wrong_fragment', 'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells', 'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login']
#
# ✅ Categorical features encoded!

# %%
# Cell 30: Split into Train/Validation Sets
from sklearn.model_selection import train_test_split

print("="*60)
print("STEP 4: Split Train/Validation Sets")
print("="*60)

# Split: 80% train, 20% validation
X_train, X_val, y_train, y_val = train_test_split(
    X_encoded, 
    y, 
    test_size=0.2,      # 20% for validation
    random_state=42,    # For reproducibility
    stratify=y          # Keep same ratio of 0/1 in both sets
)

print(f"Original data: {X_encoded.shape[0]} samples")
print(f"\nTraining set: {X_train.shape[0]} samples")
print(f"Validation set: {X_val.shape[0]} samples")

# Check label distribution
print(f"\n--- Training set label distribution ---")
print(y_train.value_counts())
print(f"Ratio: {y_train.value_counts()[0] / y_train.value_counts()[1]:.2f}")

print(f"\n--- Validation set label distribution ---")
print(y_val.value_counts())
print(f"Ratio: {y_val.value_counts()[0] / y_val.value_counts()[1]:.2f}")

print("\n✅ Data split complete!")
# Out:
# ...
# STEP 4: Split Train/Validation Sets
# ...
# Original data: 125973 samples
#
# Training set: 100778 samples
# Validation set: 25195 samples
#
# --- Training set label distribution ---
# binary_label
# 0    53874
# 1    46904
# Name: count, dtype: int64
# Ratio: 1.15
#
# --- Validation set label distribution ---
# binary_label
# 0    13469
# 1    11726
# Name: count, dtype: int64
# Ratio: 1.15
#
# ✅ Data split complete!

# %%
# Cell 31: Final Verification
print("="*60)
print("STEP 5: Preprocessing Complete - Verification")
print("="*60)

print("✅ Training data ready:")
print(f"   X_train: {X_train.shape} (samples, features)")
print(f"   y_train: {y_train.shape} (labels)")

print("\n✅ Validation data ready:")
print(f"   X_val: {X_val.shape}")
print(f"   y_val: {y_val.shape}")

print(f"\n✅ All features are numerical:")
print(f"   Data types: {X_train.dtypes.value_counts()}")

print(f"\n✅ No missing values:")
print(f"   Missing in X_train: {X_train.isnull().sum().sum()}")
print(f"   Missing in y_train: {y_train.isnull().sum()}")

print("\n" + "="*60)
print("🎉 PREPROCESSING COMPLETE! Ready for training!")
print("="*60)
# Out:
# ...
# STEP 5: Preprocessing Complete - Verification
# ...
# ✅ Training data ready:
#    X_train: (100778, 122) (samples, features)
#    y_train: (100778,) (labels)
#
# ✅ Validation data ready:
#    X_val: (25195, 122)
#    y_val: (25195,)
#
# ✅ All features are numerical:
#    Data types: bool       84
# int64      23
# float64    15
# Name: count, dtype: int64
#
# ✅ No missing values:
#    Missing in X_train: 0
#    Missing in y_train: 0
#
# ...
# 🎉 PREPROCESSING COMPLETE! Ready for training!
# ...

# %%
train_df['service'].value_counts()
# Out:
# service
# http         40338
# private      21853
# domain_u      9043
# smtp          7313
# ftp_data      6860
#              ...
# tftp_u           3
# http_8001        2
# aol              2
# harvest          2
# http_2784        1
# Name: count, Length: 70, dtype: int64
